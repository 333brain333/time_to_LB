# %%
# %pylab
# Out:
# Using matplotlib backend: Qt4Agg
# Populating the interactive namespace from numpy and matplotlib

# %%
import pandas as pd


g=pd.read_csv('meteor1.csv', sep=';', decimal=',', usecols='L') # generated output data from time_to_LB 
g.replace(g)
s_d=pd.read_csv('METEOR_M1_20091007 (2).csv', sep=',', decimal='.',header=None, usecols=[1]) # sourse data

a=[0]*len(g>99,99)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-69-862ede26b7a4> in <module>()
#       3
#       4 g=pd.read_csv('meteor1.csv', sep=';', decimal=',', usecols='L') # generated output data from time_to_LB
# ----> 5 g.replace(g)
#       6 s_d=pd.read_csv('METEOR_M1_20091007 (2).csv', sep=',', decimal='.',header=None, usecols=[1]) # sourse data
#       7
#
# C:\Anaconda3\lib\site-packages\pandas\core\generic.py in replace(self, to_replace, value, inplace, limit, regex, method, axis)
#    3323             if isinstance(to_replace, (tuple, list)):
#    3324                 return _single_replace(self, to_replace, method, inplace,
# -> 3325                                        limit)
#    3326
#    3327             if not is_dictlike(to_replace):
#
# C:\Anaconda3\lib\site-packages\pandas\core\generic.py in _single_replace(self, to_replace, method, inplace, limit)
# ...

# %%
g_e=a+list(g['L'])+a

# %%
s_d.plot()

# %%
g.replace?

# %%
g>99
# Out:
#           L
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# ...     ...
# 8878   True
# 8879  False
# 8880  False
# 8881  False
# 8882  False
# 8883  False
# 8884  False
# 8885  False
# 8886  False
# 8887  False
# 8888  False
# 8889  False
# 8890  False
# 8891  False
# 8892  False
# 8893  False
# 8894  False
# 8895  False
# 8896  False
# 8897  False
# 8898  False
# 8899  False
# 8900  False
# 8901  False
# 8902  False
# 8903  False
# 8904  False
# 8905  False
# 8906  False
# 8907  False
#
# [8908 rows x 1 columns]
